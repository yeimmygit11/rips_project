# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from math import ceil
import seaborn as sns

# %%
#Define paths 

csv_path = os.path.abspath(
    os.path.join("..", "data", "interim", "05_-_Antioquia_2021_clean.csv")
)
csv_clean_path = os.path.abspath(
    os.path.join("..", "data", "processed", "05_-_Antioquia_2021_processed.csv")
)

# %%
# Read Csv
df = pd.read_csv(csv_path)
df.head()
# Out:
#     a_o tipoatencion  numeroatenciones  codigo_departamento  \
# 0  2021    CONSULTAS                 1                    5
# 1  2021    CONSULTAS                 1                    5
# 2  2021    CONSULTAS                 1                    5
# 3  2021    CONSULTAS                 1                    5
# 4  2021    CONSULTAS                 1                    5
#
#   nombre_departamento  codigo_municipio nombre_municipio codigo_diagnostico  \
# 0           Antioquia              5501            Olaya               E02X
# 1           Antioquia              5501            Olaya               F069
# 2           Antioquia              5501            Olaya               F412
# 3           Antioquia              5501            Olaya               F510
# 4           Antioquia              5501            Olaya               F529
#
#                                        n_diagnostico
# 0  HIPOTIROIDISMO SUBCLINICO POR DEFICIENCIA DE YODO
# 1  TRASTORNO MENTAL NO ESPECIFICADO DEBIDO A LESI...
# 2            TRASTORNO MIXTO DE ANSIEDAD Y DEPRESION
# 3                               INSOMNIO NO ORGANICO
# 4  DISFUNCION SEXUAL, NO OCASIONADA POR TRASTORNO...

# %%
df.shape
# Out:
# (395047, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395047 entries, 0 to 395046
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   a_o                  395047 non-null  int64
#  1   tipoatencion         395047 non-null  object
#  2   numeroatenciones     395047 non-null  int64
#  3   codigo_departamento  395047 non-null  int64
#  4   nombre_departamento  395047 non-null  object
#  5   codigo_municipio     395047 non-null  int64
#  6   nombre_municipio     395047 non-null  object
#  7   codigo_diagnostico   395047 non-null  object
#  8   n_diagnostico        395047 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 27.1+ MB

# %%
# Evaluating nulls in df

df.isna().sum().sort_values(ascending = False)
# Out:
# a_o                    0
# tipoatencion           0
# numeroatenciones       0
# codigo_departamento    0
# nombre_departamento    0
# codigo_municipio       0
# nombre_municipio       0
# codigo_diagnostico     0
# n_diagnostico          0
# dtype: int64

# %%
# Detect strings out of ASCII range (basics) - Municipio
mask_non_ascii = df['nombre_municipio'].apply(lambda x: any(ord(c) > 127 for c in str(x)))
errors_non_ascii = df[mask_non_ascii]

print("Entries with non-ASCII characters:")
print(errors_non_ascii['nombre_municipio'].unique())

df['nombre_municipio'] = df['nombre_municipio'].str.replace('A¡', 'a', regex=False)

print(sorted(df['nombre_municipio'].unique()))
# Out:
# Entries with non-ASCII characters:
# ['San Juan De UrabA¡' 'Santa BA¡rbara' 'CocornA¡' 'CA¡ceres' 'BuriticA¡'
#  'MutatA¡' 'TarazA¡' 'TA¡mesis' 'SopetrA¡n' 'AmagA¡']
# ['Abejorral', 'Abriaqui', 'Alejandria', 'Amaga', 'Amalfi', 'Andes', 'Angelopolis', 'Angostura', 'Anori', 'Anza', 'Apartado', 'Arboletes', 'Argelia', 'Armenia', 'Barbosa', 'Bello', 'Belmira', 'Betania', 'Betulia', 'Briceno', 'Buritica', 'Caceres', 'Caicedo', 'Caldas', 'Campamento', 'Canasgordas', 'Caracoli', 'Caramanta', 'Carepa', 'Carolina', 'Caucasia', 'Chigorodo', 'Cisneros', 'Ciudad Bolivar', 'Cocorna', 'Concepcion', 'Concordia', 'Copacabana', 'Dabeiba', 'Don Matias', 'Ebejico', 'El Bagre', 'El Carmen De Viboral', 'El Santuario', 'Entrerrios', 'Envigado', 'Fredonia', 'Frontino', 'Giraldo', 'Girardota', 'Gomez Plata', 'Granada', 'Guadalupe', 'Guarne', 'Guatape', 'Heliconia', 'Hispania', 'Itagui', 'Ituango', 'Jardin', 'Jerico', 'La Ceja', 'La Estrella', 'La Pintada', 'La Union', 'Liborina', 'Maceo', 'Marinilla', 'Medellin', 'Montebello', 'Murindo', 'Mutata', 'Narino', 'Nechi', 'Necocli', 'Olaya', 'Penol', 'Peque', 'Pueblorrico', 'Puerto Berrio', 'Puerto Nare', 'Puerto Triunfo', 'Remedios', 'Retiro', 'Rionegro', 'Sabanalarga', 'Sabaneta', 'Salgar', 'San Andres De Cuerquia', 'San Carlos', 'San Francisco', 'San Jeronimo', 'San Jose De La Montana', 'San Juan De Uraba', 'San Luis', 'San Pedro', 'San Pedro De Uraba', 'San Rafael', 'San Roque', 'San Vicente', 'Santa Barbara', 'Santa Rosa De Osos', 'Santafe De Antioquia', 'Santo Domingo', 'Segovia', 'Sin Informacion - Antioquia', 'Sonson', 'Sopetran', 'Tamesis', 'Taraza', 'Tarso', 'Titiribi', 'Toledo', 'Turbo', 'Uramita', 'Urrao', 'Valdivia', 'Valparaiso', 'Vegachi', 'Venecia', 'Vigia Del Fuerte', 'Yali', 'Yarumal', 'Yolombo', 'Yondo', 'Zaragoza']

# %%
# Detect strings out of ASCII range (basics) - Diagnostico

mask_non_ascii = df['n_diagnostico'].apply(lambda x: any(ord(c) > 127 for c in str(x)))
errores_non_ascii = df[mask_non_ascii]
print("Entries with non-ASCII characters:")
print(errores_non_ascii['n_diagnostico'].unique())

df['n_diagnostico'] = df['n_diagnostico'].str.replace(r'\s*\([^)]*\)', '', regex=True).str.strip()
print(sorted(df['n_diagnostico'].unique()))
# Out:
# Entries with non-ASCII characters:
# ['DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER, ATIPICA O DE TIPO MIXTO (G30.8†)'
#  'SINDROME SECO  SJA–GREN '
#  'RETINOPATIA DIABETICA (E10-E14† CON CUARTO CARACTER COMUN .3)'
#  'BURSITIS GONOCOCICA (A54.4†)'
#  'DEMENCIA EN LA ENFERMEDAD DE PARKINSON (G20†)'
#  'EXOFTALMIA HIPERTIROIDEA (E05.-†)'
#  'QUERATITIS Y QUERATOCONJUNTIVITIS POR HERPES SIMPLE (B00.5†)'
#  'DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER, DE COMIENZO TEMPRANO (G30.0†)'
#  'ARTROPATIA PSORIASICA INTERFALANGICA DISTAL (L40.5†)'
#  'OSTEITIS DEFORMANTE EN ENFERMEDAD NEOPLASICA (C00-D48†)'
#  'ARTRITIS EN RUBEOLA (B06.8†)'
#  'INFECCION TUBERCULOSA DEL CUELLO DEL UTERO (A18.1†)'
#  'OTROS SINDROMES LACUNARES (I60-I67†)' 'TUBERCULOSA (A18.0†)'
#  'COMPRESIONES DE LAS RAICES Y PLEXOS NERVIOSOS EN ENFERMEDADES NEOPLASICAS (C00-D48†)'
#  'POLINEUROPATIA EN OTRAS ENFERMEDADES ENDOCRINAS Y METABOLICAS (E00-E07†, E15-E16†, E20-E34†, E70-E89†)'
#  'ARTRITIS MENINGOCOCICA (A39.8†)'
#  'ARTRITIS EN LA ENFERMEDAD DE LYME (A69.2†)'
#  'ENFERMEDAD INFLAMATORIA PELVICA FEMENINA POR GONOCOCOS (A54.2†)'
#  'PARALISIS MULTIPLE DE LOS NERVIOS CRANEALES EN ENFERMEDADES INFECCIOSAS Y PARASITARIAS CLASIFICADAS EN OTRA PARTE (A00-B99†)'
#  'ESPONDILITIS PSORIASICA (L40.5†)'
#  'ARTROPATIA EN LA ENFERMEDAD DE CROHN (ENTERITIS REGIONAL) (K50.-†)'
#  'SIFILIS RENAL TARDIA (A52.7†)' 'ARTROPATIA EN LA AMILOIDOSIS (E85.-†)'
#  'ERITEMA MARGINADO EN LA FIEBRE REUMATICA AGUDA (I00†)'
#  'ILEO MECONIAL (E84.1†)'
#  'COMPRESIONES DE LAS RAICES Y PLEXOS NERVIOSOS EN OTRAS DORSOPATIAS (M45-M46†, M48.-†, M53-M54†)'
#  'ARTROPATIA EN LA COLITIS ULCERATIVA (K51.-†)'
#  'TRASTORNOS GLOMERULARES EN DIABETES MELLITUS (E10-E14† CON CUARTO CARACTER COMUN .2)'
#  'SINDROME DE LA ARTERIA CEREBRAL ANTERIOR (I66.1†)'
#  'ARTROPATIA HEMOFILICA (D66-D68†)'
#  'POLINEUROPATIA EN DEFICIENCIA NUTRICIONAL (E40-E64†)'
#  'INFECCION FILARICA DE LA CONJUNTIVA (B74.-†)'
#  'OSTEONECROSIS DEBIDA A HEMOGLOBINOPATIA (D50-D64†)'
#  'TRASTORNOS RENALES TUBULOINTERSTICIALES EN RECHAZO DE TRASPLANTE (T86.-†)'
#  'POLINEUROPATIA EN OTROS TRASTORNOS OSTEOMUSCULARES (M00-M25†, M40-M96†)'
#  'ARTROPATIA EN OTROS TRASTORNOS DE LA SANGRE (D50-D76†)'
#  'ESPONDILITIS POR ENTEROBACTERIAS (A01-A04†)'
#  'ESOFAGITIS TUBERCULOSA (A18.†)'
#  'PARALISIS MULTIPLE DE LOS NERVIOS CRANEALES, EN ENFERMEDADES NEOPLASICAS (C00-D48†)'
#  'MIOSITIS EN SARCOIDOSIS (D86.8†)'
#  'PARALISIS MULTIPLE DE LOS NERVIOS CRANEALES, EN LA SARCOIDOSIS (D86.8†)'
#  'ANGIOPATIA CEREBRAL AMILOIDE (E85.-†)' 'BURSITIS SIFILITICA (A52.7†)'
#  'CISTITIS TUBERCULOSA (A18.1†)'
'ABSCESO DEL PULMON SIN NEUMONIA', 'ABSCESO DEL TIMO', 'ABSCESO EXTRADURAL Y SUBDURAL, NO ESPECIFICADO', 'ABSCESO INTRAESFINTERIANO', 'ABSCESO ISQUIORRECTAL', 'ABSCESO PERIAMIGDALINO', 'ABSCESO PERIAPICAL CON FISTULA', 'ABSCESO PERIAPICAL SIN FISTULA', 'ABSCESO RECTAL', 'ABSCESO RENAL Y PERIRRENAL', 'ABSCESO RETROFARINGEO Y PARAFARINGEO', 'ABSCESO URETRAL', 'ABSCESO VULVAR', 'ABSCESO Y GRANULOMA INTRACRANEAL', 'ABSCESO Y GRANULOMA INTRARRAQUIDEO', 'ABSCESO Y QUISTE SUBCUTANEO FEOMICOTICO', 'ABSCESO, FURUNCULO Y ANTRAX DE LA NARIZ', 'ABUSO DE SUSTANCIAS QUE NO PRODUCEN DEPENDENCIA', 'ABUSO FISICO', 'ABUSO PSICOLOGICO', 'ABUSO SEXUAL', 'ACALASIA DEL CARDI ...

# %%
#Evaluating duplicate rows

duplicados = df.duplicated().sum()
print(f'Filas duplicadas: {duplicados}')
df = df.drop_duplicates()
print(df.shape)
# Out:
# Filas duplicadas: 116773
# (278274, 9)

# %%
#Evaluating numeroatenciones, searching for outliers 

print(df['numeroatenciones'].describe())
# Out:
# count    2.782740e+05
# mean     7.792001e+01
# std      6.585246e+03
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      3.000000e+00
# 75%      9.000000e+00
# max      3.252558e+06
# Name: numeroatenciones, dtype: float64

# %%
sns.histplot(df['numeroatenciones'], bins=100)
plt.xlim(0, 1000)  # Zoom para ver valores bajos
plt.title("Distribución de número de atenciones")
plt.show()

# Ver top 10 más altos
print(df[['nombre_municipio', 'n_diagnostico', 'numeroatenciones']].sort_values(by='numeroatenciones', ascending=False).head(10))
# Out:
#        nombre_municipio                                      n_diagnostico  \
# 118471         Medellin                                        NO DEFINIDO
# 206868         Medellin                      OTRAS CONSULTAS ESPECIFICADAS
# 139614         Medellin                              HIPERTENSION ESENCIAL
# 118210         Medellin                    COVID-19, VIRUS NO IDENTIFICADO
# 31954          Medellin                               CARIES DE LA DENTINA
# 215632            Bello                      OTRAS CONSULTAS ESPECIFICADAS
# 204870         Medellin                           OTROS EXAMENES GENERALES
# 31345          Medellin                       COVID-19, VIRUS IDENTIFICADO
# 330520            Bello  OTROS SINTOMAS Y SIGNOS QUE INVOLUCRAN LAS SEN...
# 32535          Medellin                      EXAMEN DE OJOS Y DE LA VISION
#
#         numeroatenciones
# 118471           3252558
# 206868            861845
# 139614            568924
# 118210            231205
# 31954             223321
# 215632            159665
# 204870            154987
# 31345             149567
# 330520            122564
# 32535             117220

# %% [markdown]
# These are not outliers; a very large number of medical services rendered is expected in larger cities like Medellín compared to smaller towns.

# %%
df.to_csv(csv_clean_path, index=False, encoding='utf-8')
print(f"\n✅ Processed file saved at:\n{csv_clean_path}")
# Out:
# ✅ Processed file saved at:
# /home/ym0r4l3s/projects/RIPS_Project/rips_project/data/processed/05_-_Antioquia_2021_processed.csv
